# %%
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:/Users/rocka/OneDrive/Desktop/Sem1GMU/AIT 580/Final Project/statewideca.csv")

# %%
df.head()
# Out:
#    Year Year Index  Surgery  # of Cases
# 0  2013      Year1    Colon        7128
# 1  2013      Year1  Bladder         892
# 2  2013      Year1   Rectum        2128
# 3  2013      Year1   Breast       25829
# 4  2013      Year1    Brain        2719

# %%
df_filtered = df[df['Year'] != 2015]

Statewide_statistics = df_filtered.groupby('Surgery')['# of Cases'].describe()

print(Statewide_statistics)
# Out:
#            count       mean          std      min       25%      50%  \
# Surgery
# Bladder      8.0    960.875    59.016795    892.0    927.75    951.5
# Brain        8.0   3186.875   261.130202   2719.0   3086.00   3290.5
# Breast       8.0  27996.625  2024.130497  25290.0  26525.75  27829.5
# Colon        8.0   7354.500   299.327341   6736.0   7283.25   7424.5
# Esophagus    8.0    430.125    60.328713    337.0    396.00    440.5
# Liver        8.0   1466.000   173.207555   1159.0   1359.50   1513.0
# Lung         8.0   3160.875    96.386777   3028.0   3106.00   3152.0
# Pancreas     8.0   1029.875   114.558079    819.0   1021.00   1080.5
# Prostate     8.0   5283.375  1294.028917   3268.0   4663.25   5383.0
# Rectum       8.0   3017.625   518.899092   2128.0   2935.75   3292.0
# Stomach      8.0    994.250    37.579440    948.0    966.75    989.0
#
#                 75%      max
# Surgery
# Bladder      983.75   1054.0
# Brain       3372.00   3413.0
# ...

# %%
# Defining a custom color palette with distinct colors
custom_palette = sb.color_palette(["#1f78b4", "#ff7f00", "#33a02c", "#e31a1c", "#6a3d9a", "#a6cee3", "#b2df8a", "#fb9a99", "#fdbf6f", "#cab2d6", "#ffff99"], n_colors=len(df['Surgery'].unique()))

plt.figure(figsize=(10, 6))


for i, surgery in enumerate(df['Surgery'].unique()):
    surgery_data = df[df['Surgery'] == surgery]
    plt.plot(surgery_data['Year'], surgery_data['# of Cases'], label=surgery, color=custom_palette[i])


plt.xlabel('Year')
plt.ylabel('# of Cases')
plt.title('Cancer Surgeries in California (2013-2021)')
plt.legend()  

plt.show()

# %%
# Defining a custom color palette with distinct colors
custom_palette = sb.color_palette(["#1f78b4", "#ff7f00", "#33a02c", "#e31a1c", "#6a3d9a", "#a6cee3", "#b2df8a", "#fb9a99", "#fdbf6f", "#cab2d6", "#ffff99"], n_colors=len(df['Surgery'].unique()))

plt.figure(figsize=(10, 6))


for i, surgery in enumerate(df['Surgery'].unique()):
    surgery_data = df[df['Surgery'] == surgery]
    plt.scatter(surgery_data['# of Cases'], surgery_data['Year'], label=surgery, color=custom_palette[i])

plt.xlabel('Number of Cases')
plt.ylabel('Year')
plt.title('Cancer Surgeries in California (2013-2021)')


plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

# %%
breast_data = df[df['Surgery'] == 'Breast']


plt.figure(figsize=(10, 6))
plt.plot(breast_data['Year'], breast_data['# of Cases'], marker='o', linestyle='-', color='g')


for i, txt in enumerate(breast_data['# of Cases']):
    plt.annotate(txt, (breast_data['Year'].iloc[i], breast_data['# of Cases'].iloc[i]), textcoords="offset points", xytext=(0,5), ha='center')


plt.xlabel('Year')
plt.ylabel('# of Cases')
plt.title('Breast Cancer Surgeries in California (2013-2021)')


plt.show()

# %%
colon_data = df[df['Surgery'] == 'Colon']


plt.figure(figsize=(10, 6))
plt.plot(colon_data['Year'], colon_data['# of Cases'], marker='o', linestyle='-', color='c')


for i, txt in enumerate(colon_data['# of Cases']):
    plt.annotate(txt, (colon_data['Year'].iloc[i], colon_data['# of Cases'].iloc[i]), textcoords="offset points", xytext=(0,5), ha='center')


plt.xlabel('Year')
plt.ylabel('# of Cases')
plt.title('Colon Cancer Surgeries in California (2013-2021)')


plt.show()

# %%
bladder_data = df[df['Surgery'] == 'Bladder']

# Plotting for Bladder surgeries
plt.figure(figsize=(10, 6))
plt.plot(bladder_data['Year'], bladder_data['# of Cases'], marker='o', linestyle='-', color='r')

# Add labels for each data point
for i, txt in enumerate(bladder_data['# of Cases']):
    plt.annotate(txt, (bladder_data['Year'].iloc[i], bladder_data['# of Cases'].iloc[i]), textcoords="offset points", xytext=(0,5), ha='center')

# Set labels and title
plt.xlabel('Year')
plt.ylabel('# of Cases')
plt.title('Bladder Cancer Surgeries in California (2013-2021)')

# Display the plot
plt.show()

# %%
rectum_data = df[df['Surgery'] == 'Rectum']

# Plotting for Rectum surgeries
plt.figure(figsize=(10, 6))
plt.plot(rectum_data['Year'], rectum_data['# of Cases'], marker='o', linestyle='-', color='pink')

# Add labels for each data point
for i, txt in enumerate(rectum_data['# of Cases']):
    plt.annotate(txt, (rectum_data['Year'].iloc[i], rectum_data['# of Cases'].iloc[i]), textcoords="offset points", xytext=(0,5), ha='center')


# Set labels and title
plt.xlabel('Year')
plt.ylabel('# of Cases')
plt.title('Rectum Cancer Surgeries in California (2013-2021)')

# Display the plot
plt.show()

# %%
pancreas_data = df[df['Surgery'] == 'Pancreas']

# Plotting for Pancreas surgeries
plt.figure(figsize=(10, 6))
plt.plot(pancreas_data['Year'], pancreas_data['# of Cases'], marker='o', linestyle='-', color='orange')

# Add labels for each data point
for i, txt in enumerate(pancreas_data['# of Cases']):
    plt.annotate(txt, (pancreas_data['Year'].iloc[i], pancreas_data['# of Cases'].iloc[i]), textcoords="offset points", xytext=(0,5), ha='center')


# Set labels and title
plt.xlabel('Year')
plt.ylabel('# of Cases')
plt.title('Pancreas Cancer Surgeries in California (2013-2021)')

# Display the plot
plt.show()

# %%
lung_data = df[df['Surgery'] == 'Lung']

# Plotting for Lung surgeries
plt.figure(figsize=(10, 6))
plt.plot(lung_data['Year'], lung_data['# of Cases'], marker='o', linestyle='-', color='cyan')

# Add labels for each data point
for i, txt in enumerate(lung_data['# of Cases']):
    plt.annotate(txt, (lung_data['Year'].iloc[i], lung_data['# of Cases'].iloc[i]), textcoords="offset points", xytext=(0,5), ha='center')


# Set labels and title
plt.xlabel('Year')
plt.ylabel('# of Cases')
plt.title('Lung Cancer Surgeries in California (2013-2021)')

# Display the plot
plt.show()

# %%
liver_data = df[df['Surgery'] == 'Liver']

# Plotting for Liver surgeries
plt.figure(figsize=(10, 6))
plt.plot(liver_data['Year'], liver_data['# of Cases'], marker='o', linestyle='-', color='magenta')

# Add labels for each data point
for i, txt in enumerate(liver_data['# of Cases']):
    plt.annotate(txt, (liver_data['Year'].iloc[i], liver_data['# of Cases'].iloc[i]), textcoords="offset points", xytext=(0,5), ha='center')


# Set labels and title
plt.xlabel('Year')
plt.ylabel('# of Cases')
plt.title('Liver Cancer Surgeries in California (2013-2021)')

# Display the plot
plt.show()

# %%
esophagus_data = df[df['Surgery'] == 'Esophagus']

# Plotting for Esophagus surgeries
plt.figure(figsize=(10, 6))
plt.plot(esophagus_data['Year'], esophagus_data['# of Cases'], marker='o', linestyle='-', color='orange')

# Add labels for each data point
for i, txt in enumerate(esophagus_data['# of Cases']):
    plt.annotate(txt, (esophagus_data['Year'].iloc[i], esophagus_data['# of Cases'].iloc[i]), textcoords="offset points", xytext=(0,5), ha='center')

# Set labels and title
plt.xlabel('Year')
plt.ylabel('# of Cases')
plt.title('Esophagus Cancer Surgeries in California (2013-2021)')

# Display the plot
plt.show()

# %%
stomach_data = df[df['Surgery'] == 'Stomach']

# Plotting for Stomach surgeries
plt.figure(figsize=(10, 6))
plt.plot(stomach_data['Year'], stomach_data['# of Cases'], marker='o', linestyle='-', color='green')

# Add labels for each data point
for i, txt in enumerate(stomach_data['# of Cases']):
    plt.annotate(txt, (stomach_data['Year'].iloc[i], stomach_data['# of Cases'].iloc[i]), textcoords="offset points", xytext=(0,5), ha='center')

# Set labels and title
plt.xlabel('Year')
plt.ylabel('# of Cases')
plt.title('Stomach Cancer Surgeries in California (2013-2021)')

# Display the plot
plt.show()

# %%
prostate_data = df[df['Surgery'] == 'Prostate']

# Plotting for Prostate surgeries
plt.figure(figsize=(10, 6))
plt.plot(prostate_data['Year'], prostate_data['# of Cases'], marker='o', linestyle='-', color='cyan')

# Add labels for each data point
for i, txt in enumerate(prostate_data['# of Cases']):
    plt.annotate(txt, (prostate_data['Year'].iloc[i], prostate_data['# of Cases'].iloc[i]), textcoords="offset points", xytext=(0,5), ha='center')

# Set labels and title
plt.xlabel('Year')
plt.ylabel('# of Cases')
plt.title('Prostate Cancer Surgeries in California (2013-2021)')

# Display the plot
plt.show()

# %%
brain_data = df[df['Surgery'] == 'Brain']

# Plotting for Brain surgeries
plt.figure(figsize=(10, 6))
plt.plot(brain_data['Year'], brain_data['# of Cases'], marker='o', linestyle='-', color='purple')

# Add labels for each data point
for i, txt in enumerate(brain_data['# of Cases']):
    plt.annotate(txt, (brain_data['Year'].iloc[i], brain_data['# of Cases'].iloc[i]), textcoords="offset points", xytext=(0,5), ha='center')

# Set labels and title
plt.xlabel('Year')
plt.ylabel('# of Cases')
plt.title('Brain Cancer Surgeries in California (2013-2021)')

# Display the plot
plt.show()

# %%
total_cases_by_year_index = df.groupby('Year Index')['# of Cases'].sum().reset_index()

# Display the result
print(total_cases_by_year_index)
# Out:
#   Year Index  # of Cases
# 0      Year1       51311
# 1      Year2       50881
# 2      Year3       39454
# 3      Year4       56291
# 4      Year5       57461
# 5      Year6       57232
# 6      Year7       58074
# 7      Year8       51555
# 8      Year9       56243

# %%
df1 = pd.read_csv("C:/Users/rocka/OneDrive/Desktop/Sem1GMU/AIT 580/Final Project/cadatawosw.csv")

# %%
total_cases_by_year_index = df.groupby('Year Index')['# of Cases'].sum().reset_index()


plt.figure(figsize=(8, 5))
bars = plt.bar(total_cases_by_year_index['Year Index'], total_cases_by_year_index['# of Cases'], color='blue')


for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 1), ha='center', va='bottom')


plt.xlabel('Year Index')
plt.ylabel('Total # of Cases')
plt.title('Total Number of Cases by Year Index')


plt.show()

# %%
total_surgeries_per_year = df.groupby('Year')['# of Cases'].sum().reset_index()

plt.figure(figsize=(10, 7))
plt.plot(total_surgeries_per_year['Year'], total_surgeries_per_year['# of Cases'], marker='o', color='Blue', linestyle='-')
plt.title('Total Number of Surgeries Performed Each Year')
plt.xlabel('Year')
plt.ylabel('Total Number of Surgeries')


for i, txt in enumerate(total_surgeries_per_year['# of Cases']):
    plt.annotate(txt, (total_surgeries_per_year['Year'].iloc[i], total_surgeries_per_year['# of Cases'].iloc[i] + 500))

plt.grid(axis='y', linestyle='-', alpha=0.7)
plt.show()

# %%
df1.head()
# Out:
#    Year Year Index   County  \
# 0  2013      Year1  Alameda
# 1  2013      Year1  Alameda
# 2  2013      Year1  Alameda
# 3  2013      Year1  Alameda
# 4  2013      Year1  Alameda
#
#                                             Hospital    OSHPDID  Surgery  \
# 0                                   Alameda Hospital  106010735  Stomach
# 1                                   Alameda Hospital  106010735    Colon
# 2                                   Alameda Hospital  106010735   Breast
# 3  Alta Bates Summit Medical Center – Alta Bates ...  106010739    Brain
# 4  Alta Bates Summit Medical Center – Alta Bates ...  106010739    Colon
#
#    nCases
# 0       1
# 1       3
# 2       2
# 3       8
# 4      12

# %%
# Group by Surgery and compute statistics for 'nCases'
Statewide_statistics = df1.groupby('Surgery')['nCases'].describe()

# Print the statistics
print(Statewide_statistics)
# Out:
#             count       mean         std  min   25%   50%     75%    max
# Surgery
# Bladder    1055.0   7.927962   17.098845  1.0   1.0   2.0    6.00  177.0
# Brain      1241.0  22.244964   37.628184  1.0   5.0  10.0   22.00  354.0
# Breast     2537.0  96.132046  119.562717  1.0  15.0  51.0  132.00  813.0
# Colon      2596.0  24.765794   23.374373  1.0   7.0  17.0   37.25  163.0
# Esophagus   706.0   5.247875    7.195903  1.0   1.0   2.0    6.00   57.0
# Liver      1230.0  10.308943   20.595618  1.0   1.0   3.0    8.00  152.0
# Lung       1529.0  18.178548   23.842940  1.0   3.0   9.0   24.00  205.0
# Pancreas   1054.0   8.439279   13.121668  1.0   1.0   3.0    9.00  100.0
# Prostate   1653.0  28.276467   48.677328  1.0   2.0  10.0   30.00  435.0
# Rectum     2242.0  11.524978   14.240760  1.0   2.0   6.0   16.00  115.0
# Stomach    1675.0   5.192836    6.323833  1.0   1.0   3.0    6.00   54.0

# %%
# Filter data for the year 2013
df1_2013 = df1[df1['Year'] == 2013]

# Group by Surgery and County, then find the top county for each surgery
top_counties_2013 = df1_2013.groupby(['Surgery', 'County'])['nCases'].sum().reset_index()
top_counties_2013 = top_counties_2013.sort_values(by=['Surgery', 'nCases'], ascending=[True, False])
top_counties_2013 = top_counties_2013.groupby('Surgery').head(3)

# Display the result
print(top_counties_2013)

# Create a bar plot
plt.figure(figsize=(12, 8))
for surgery, data in top_counties_2013.groupby('Surgery'):
    plt.bar(data['County'], data['nCases'], label=surgery)

# Set labels and title
plt.xlabel('County')
plt.ylabel('Total # of Cases')
plt.title('Top 3 Counties for Each Surgery in 2013')
plt.legend()

# Display the plot
plt.show()
# Out:
#        Surgery         County  nCases
# 8      Bladder    Los Angeles     368
# 21     Bladder    Santa Clara      94
# 15     Bladder      San Diego      74
# 36       Brain    Los Angeles     772
# 46       Brain  San Francisco     364
# 40       Brain         Orange     284
# 73      Breast    Los Angeles    6561
# 88      Breast      San Diego    2397
# 81      Breast         Orange    2311
# 124      Colon    Los Angeles    1914
# 139      Colon      San Diego     683
# 132      Colon         Orange     600
# 163  Esophagus    Los Angeles     123
# 165  Esophagus         Orange      28
# 159  Esophagus        Alameda      24
# 189      Liver    Los Angeles     422
# 199      Liver  San Francisco     153
# 204      Liver    Santa Clara     148
# 219       Lung    Los Angeles     900
# 225       Lung         Orange     298
# 230       Lung      San Diego     238
# 251   Pancreas    Los Angeles     274
# 254   Pancreas         Orange     103
# 265   Pancreas    Santa Clara     101
# ...

# %%
# Filter data for the year 2014
df1_2014 = df1[df1['Year'] == 2014]

# Group by Surgery and County, then find the top county for each surgery
top_counties_2014 = df1_2014.groupby(['Surgery', 'County'])['nCases'].sum().reset_index()
top_counties_2014 = top_counties_2014.sort_values(by=['Surgery', 'nCases'], ascending=[True, False])
top_counties_2014 = top_counties_2014.groupby('Surgery').head(3)

# Display the result
print(top_counties_2014)

# Create a bar plot
plt.figure(figsize=(12, 8))
for surgery, data in top_counties_2014.groupby('Surgery'):
    plt.bar(data['County'], data['nCases'], label=surgery)

# Set labels and title
plt.xlabel('County')
plt.ylabel('Total # of Cases')
plt.title('Top 3 Counties for Each Surgery in 2014')
plt.legend()

# Display the plot
plt.show()
# Out:
#        Surgery         County  nCases
# 6      Bladder    Los Angeles     362
# 19     Bladder    Santa Clara     102
# 14     Bladder      San Diego      78
# 35       Brain    Los Angeles     777
# 45       Brain  San Francisco     351
# 39       Brain         Orange     314
# 72      Breast    Los Angeles    6175
# 87      Breast      San Diego    2632
# 80      Breast         Orange    2243
# 122      Colon    Los Angeles    1977
# 137      Colon      San Diego     648
# 130      Colon         Orange     584
# 162  Esophagus    Los Angeles     118
# 165  Esophagus         Orange      32
# 170  Esophagus      San Diego      28
# 191      Liver    Los Angeles     503
# 199      Liver  San Francisco     172
# 203      Liver    Santa Clara     155
# 217       Lung    Los Angeles     913
# 223       Lung         Orange     311
# 228       Lung      San Diego     275
# 249   Pancreas    Los Angeles     286
# 253   Pancreas         Orange     125
# 259   Pancreas  San Francisco     125
# ...

# %%
# Filter data for the year 2015
df1_2015 = df1[df1['Year'] == 2015]

# Group by Surgery and County, then find the top county for each surgery
top_counties_2015 = df1_2015.groupby(['Surgery', 'County'])['nCases'].sum().reset_index()
top_counties_2015 = top_counties_2015.sort_values(by=['Surgery', 'nCases'], ascending=[True, False])
top_counties_2015 = top_counties_2015.groupby('Surgery').head(3)

# Display the result
print(top_counties_2015)

# Create a bar plot
plt.figure(figsize=(12, 8))
for surgery, data in top_counties_2015.groupby('Surgery'):
    plt.bar(data['County'], data['nCases'], label=surgery)

# Set labels and title
plt.xlabel('County')
plt.ylabel('Total # of Cases')
plt.title('Top 3 Counties for Each Surgery in 2015')
plt.legend()

# Display the plot
plt.show()
# Out:
#        Surgery          County  nCases
# 6      Bladder     Los Angeles     269
# 20     Bladder     Santa Clara      70
# 14     Bladder       San Diego      60
# 34       Brain     Los Angeles     578
# 44       Brain   San Francisco     291
# 38       Brain          Orange     229
# 73      Breast     Los Angeles    4938
# 87      Breast       San Diego    2034
# 81      Breast          Orange    1821
# 121      Colon     Los Angeles    1451
# 135      Colon       San Diego     499
# 129      Colon          Orange     496
# 158  Esophagus     Los Angeles      76
# 172  Esophagus     Santa Clara      30
# 164  Esophagus      Sacramento      29
# 180      Liver     Los Angeles     352
# 189      Liver   San Francisco     145
# 193      Liver     Santa Clara     117
# 205       Lung     Los Angeles     709
# 211       Lung          Orange     259
# 216       Lung       San Diego     183
# 236   Pancreas     Los Angeles     230
# 244   Pancreas   San Francisco     101
# ...

# %%
# Filter data for the year 2016
df1_2016 = df1[df1['Year'] == 2016]

# Group by Surgery and County, then find the top county for each surgery
top_counties_2016 = df1_2016.groupby(['Surgery', 'County'])['nCases'].sum().reset_index()
top_counties_2016 = top_counties_2016.sort_values(by=['Surgery', 'nCases'], ascending=[True, False])
top_counties_2016 = top_counties_2016.groupby('Surgery').head(3)

# Display the result
print(top_counties_2016)

# Create a bar plot
plt.figure(figsize=(12, 8))
for surgery, data in top_counties_2016.groupby('Surgery'):
    plt.bar(data['County'], data['nCases'], label=surgery)

# Set labels and title
plt.xlabel('County')
plt.ylabel('Total # of Cases')
plt.title('Top 3 Counties for Each Surgery in 2016')
plt.legend()

# Display the plot
plt.show()
# Out:
#        Surgery          County  nCases
# 6      Bladder     Los Angeles     438
# 19     Bladder     Santa Clara     114
# 14     Bladder       San Diego      92
# 35       Brain     Los Angeles     939
# 45       Brain   San Francisco     369
# 39       Brain          Orange     332
# 73      Breast     Los Angeles    7322
# 88      Breast       San Diego    2698
# 81      Breast          Orange    2518
# 124      Colon     Los Angeles    2042
# 139      Colon       San Diego     720
# 132      Colon          Orange     629
# 164  Esophagus     Los Angeles     118
# 178  Esophagus     Santa Clara      47
# 170  Esophagus      Sacramento      43
# 192      Liver     Los Angeles     608
# 203      Liver   San Francisco     216
# 208      Liver     Santa Clara     171
# 227       Lung     Los Angeles     883
# 233       Lung          Orange     303
# 244       Lung     Santa Clara     276
# 260   Pancreas     Los Angeles     362
# 274   Pancreas     Santa Clara     127
# ...

# %%
# Filter data for the year 2017
df1_2017 = df1[df1['Year'] == 2017]

# Group by Surgery and County, then find the top county for each surgery
top_counties_2017 = df1_2017.groupby(['Surgery', 'County'])['nCases'].sum().reset_index()
top_counties_2017 = top_counties_2017.sort_values(by=['Surgery', 'nCases'], ascending=[True, False])
top_counties_2017 = top_counties_2017.groupby('Surgery').head(3)

# Display the result
print(top_counties_2017)

# Create a bar plot
plt.figure(figsize=(12, 8))
for surgery, data in top_counties_2017.groupby('Surgery'):
    plt.bar(data['County'], data['nCases'], label=surgery)

# Set labels and title
plt.xlabel('County')
plt.ylabel('Total # of Cases')
plt.title('Top 3 Counties for Each Surgery in 2017')
plt.legend()

# Display the plot
plt.show()
# Out:
#        Surgery         County  nCases
# 7      Bladder    Los Angeles     410
# 20     Bladder    Santa Clara     104
# 15     Bladder      San Diego      97
# 33       Brain    Los Angeles     961
# 43       Brain  San Francisco     409
# 37       Brain         Orange     369
# 70      Breast    Los Angeles    7712
# 78      Breast         Orange    2638
# 85      Breast      San Diego    2614
# 119      Colon    Los Angeles    1988
# 134      Colon      San Diego     703
# 127      Colon         Orange     624
# 160  Esophagus    Los Angeles     131
# 172  Esophagus    Santa Clara      58
# 167  Esophagus      San Diego      43
# 184      Liver    Los Angeles     566
# 197      Liver  San Francisco     246
# 202      Liver    Santa Clara     174
# 221       Lung    Los Angeles     957
# 227       Lung         Orange     354
# 238       Lung    Santa Clara     280
# 254   Pancreas    Los Angeles     367
# 257   Pancreas         Orange     129
# 263   Pancreas  San Francisco     127
# ...

# %%
# Filter data for the year 2018
df1_2018 = df1[df1['Year'] == 2018]

# Group by Surgery and County, then find the top county for each surgery
top_counties_2018 = df1_2018.groupby(['Surgery', 'County'])['nCases'].sum().reset_index()
top_counties_2018 = top_counties_2018.sort_values(by=['Surgery', 'nCases'], ascending=[True, False])
top_counties_2018 = top_counties_2018.groupby('Surgery').head(3)

# Display the result
print(top_counties_2018)

# Create a bar plot
plt.figure(figsize=(12, 8))
for surgery, data in top_counties_2018.groupby('Surgery'):
    plt.bar(data['County'], data['nCases'], label=surgery)

# Set labels and title
plt.xlabel('County')
plt.ylabel('Total # of Cases')
plt.title('Top 3 Counties for Each Surgery in 2018')
plt.legend()

# Display the plot
plt.show()
# Out:
#        Surgery          County  nCases
# 7      Bladder     Los Angeles     370
# 13     Bladder      Sacramento      90
# 15     Bladder       San Diego      87
# 34       Brain     Los Angeles    1034
# 44       Brain   San Francisco     368
# 38       Brain          Orange     359
# 71      Breast     Los Angeles    7904
# 79      Breast          Orange    2688
# 86      Breast       San Diego    2665
# 120      Colon     Los Angeles    2134
# 135      Colon       San Diego     720
# 128      Colon          Orange     670
# 160  Esophagus     Los Angeles     107
# 174  Esophagus     Santa Clara      60
# 155  Esophagus         Alameda      50
# 186      Liver     Los Angeles     544
# 197      Liver   San Francisco     238
# 196      Liver       San Diego     163
# 218       Lung     Los Angeles     958
# 223       Lung          Orange     359
# 228       Lung       San Diego     304
# 249   Pancreas     Los Angeles     338
# 257   Pancreas   San Francisco     133
# ...

# %%
# Filter data for the year 2019
df1_2019 = df1[df1['Year'] == 2019]

# Group by Surgery and County, then find the top county for each surgery
top_counties_2019 = df1_2019.groupby(['Surgery', 'County'])['nCases'].sum().reset_index()
top_counties_2019 = top_counties_2019.sort_values(by=['Surgery', 'nCases'], ascending=[True, False])
top_counties_2019 = top_counties_2019.groupby('Surgery').head(3)

# Display the result
print(top_counties_2019)

# Create a bar plot
plt.figure(figsize=(12, 8))
for surgery, data in top_counties_2019.groupby('Surgery'):
    plt.bar(data['County'], data['nCases'], label=surgery)

# Set labels and title
plt.xlabel('County')
plt.ylabel('Total # of Cases')
plt.title('Top 3 Counties for Each Surgery in 2019')
plt.legend()

# Display the plot
plt.show()
# Out:
#        Surgery          County  nCases
# 7      Bladder     Los Angeles     383
# 20     Bladder     Santa Clara     103
# 12     Bladder      Sacramento      89
# 35       Brain     Los Angeles    1014
# 39       Brain          Orange     358
# 45       Brain   San Francisco     349
# 73      Breast     Los Angeles    8462
# 88      Breast       San Diego    2910
# 81      Breast          Orange    2755
# 123      Colon     Los Angeles    2057
# 138      Colon       San Diego     717
# 131      Colon          Orange     664
# 162  Esophagus     Los Angeles     125
# 158  Esophagus         Alameda      61
# 177  Esophagus     Santa Clara      61
# 190      Liver     Los Angeles     569
# 197      Liver          Orange     179
# 203      Liver   San Francisco     159
# 224       Lung     Los Angeles     992
# 229       Lung          Orange     362
# 234       Lung       San Diego     310
# 256   Pancreas     Los Angeles     379
# 260   Pancreas          Orange     146
# ...

# %%
# Filter data for the year 2021
df1_2021 = df1[df1['Year'] == 2021]

# Group by Surgery and County, then find the top county for each surgery
top_counties_2021 = df1_2021.groupby(['Surgery', 'County'])['nCases'].sum().reset_index()
top_counties_2021 = top_counties_2021.sort_values(by=['Surgery', 'nCases'], ascending=[True, False])
top_counties_2021 = top_counties_2021.groupby('Surgery').head(3)

# Display the result
print(top_counties_2021)

# Create a bar plot
plt.figure(figsize=(12, 8))
for surgery, data in top_counties_2021.groupby('Surgery'):
    plt.bar(data['County'], data['nCases'], label=surgery)

# Set labels and title
plt.xlabel('County')
plt.ylabel('Total # of Cases')
plt.title('Top 3 Counties for Each Surgery in 2021')
plt.legend()

# Display the plot
plt.show()
# Out:
#        Surgery         County  nCases
# 6      Bladder    Los Angeles     397
# 21     Bladder    Santa Clara     105
# 14     Bladder     Sacramento      84
# 35       Brain    Los Angeles     999
# 45       Brain  San Francisco     400
# 39       Brain         Orange     380
# 72      Breast    Los Angeles    8144
# 87      Breast      San Diego    2826
# 80      Breast         Orange    2635
# 120      Colon    Los Angeles    2074
# 128      Colon         Orange     660
# 135      Colon      San Diego     648
# 160  Esophagus    Los Angeles     105
# 166  Esophagus     Sacramento      64
# 174  Esophagus    Santa Clara      46
# 186      Liver    Los Angeles     497
# 198      Liver  San Francisco     193
# 192      Liver         Orange     172
# 219       Lung    Los Angeles     895
# 225       Lung         Orange     309
# 236       Lung    Santa Clara     289
# 252   Pancreas    Los Angeles     346
# 264   Pancreas    Santa Clara     136
# 254   Pancreas         Orange     123
# ...

# %%
# Pivot the DataFrame for stacked bar plot
pivot_df = top_counties_2013.pivot(index='Surgery', columns='County', values='nCases').fillna(0)

# Create a stacked bar plot
plt.figure(figsize=(12, 8))
pivot_df.plot(kind='bar', stacked=True)

# Set labels and title
plt.xlabel('Surgery')
plt.ylabel('Total # of Cases')
plt.title('Top 3 Counties for Each Surgery in 2013')

# Display the plot
plt.show()

# %%
# Define a list of unique years in your dataset
unique_years = df1['Year'].unique()

# Loop through each year
for year in unique_years:
    # Filter data for the current year
    df_year = df1[df1['Year'] == year]

    # Group by Surgery and County, then find the top county for each surgery
    top_counties_year = df_year.groupby(['Surgery', 'County'])['nCases'].sum().reset_index()
    top_counties_year = top_counties_year.sort_values(by=['Surgery', 'nCases'], ascending=[True, False])
    top_counties_year = top_counties_year.groupby('Surgery').head(3)

    # Create a bar plot
    plt.figure(figsize=(12, 8))
    for surgery, data in top_counties_year.groupby('Surgery'):
        plt.bar(data['County'], data['nCases'], label=surgery)

    # Set labels and title
    plt.xlabel('County')
    plt.ylabel('Total # of Cases')
    plt.title(f'Top Counties for Each Surgery in {year}')
    plt.legend()

    plt.show()
     # Save the plot as a PNG image
    plt.savefig('county.png')

# %%
# Define a list of unique years in your dataset
unique_years = df1['Year'].unique()

# Set up subplots
fig, axes = plt.subplots(len(unique_years), 1, figsize=(15, 5 * len(unique_years)))

# Loop through each year
for i, year in enumerate(unique_years):
    # Filter data for the current year
    df_year = df1[df1['Year'] == year]

    # Group by Surgery and County, then find the top county for each surgery
    top_counties_year = df_year.groupby(['Surgery', 'County'])['nCases'].sum().reset_index()
    top_counties_year = top_counties_year.sort_values(by=['Surgery', 'nCases'], ascending=[True, False])
    top_counties_year = top_counties_year.groupby('Surgery').head(3)

    # Create a bar plot
    for surgery, data in top_counties_year.groupby('Surgery'):
        axes[i].bar(data['County'], data['nCases'], label=surgery)

    # Set labels and title for the current subplot
    axes[i].set_xlabel('County')
    axes[i].set_ylabel('Total # of Cases')
    axes[i].set_title(f'Top Counties for Each Surgery in {year}')
    axes[i].legend()

# Adjust layout
plt.tight_layout()

# Save the combined plot as a PNG image
plt.savefig('output_combined_plot.png')

# Display the plot
plt.show()

# %%
# Define a list of unique surgeries in your dataset
unique_surgeries = df1['Surgery'].unique()

# Create subplots
fig, axes = plt.subplots(len(unique_years), 1, figsize=(15, 5 * len(unique_years)))

# Loop through each year
for i, year in enumerate(unique_years):
    # Filter data for the current year
    df_year = df1[df1['Year'] == year]

    # Group by Surgery and County, then find the top county for each surgery
    top_counties_year = df_year.groupby(['Surgery', 'County'])['nCases'].sum().reset_index()
    top_counties_year = top_counties_year.sort_values(by=['Surgery', 'nCases'], ascending=[True, False])
    top_counties_year = top_counties_year.groupby('Surgery').head(3)

    # Create a bar plot for the current year
    sb.barplot(ax=axes[i], data=top_counties_year, x='County', y='nCases', hue='Surgery')

    # Set labels and title for the current subplot
    axes[i].set_xlabel('County')
    axes[i].set_ylabel('Total # of Cases')
    axes[i].set_title(f'Top 3 Counties for Each Surgery in {year}')
    axes[i].legend()

# Adjust layout
plt.tight_layout()

# Display the plot
plt.show()

# %%
df1_2014 = df1[df1['Year'] == 2014]

# Group by Surgery and County, then find the top 3 counties for each surgery
top_counties_2014 = df1_2014.groupby(['Surgery', 'County'])['nCases'].sum().reset_index()
top_counties_2014 = top_counties_2014.sort_values(by=['Surgery', 'nCases'], ascending=[True, False])
top_counties_2014 = top_counties_2014.groupby('Surgery').head(3)

# Display the result
print(top_counties_2014)
# Out:
#        Surgery         County  nCases
# 6      Bladder    Los Angeles     362
# 19     Bladder    Santa Clara     102
# 14     Bladder      San Diego      78
# 35       Brain    Los Angeles     777
# 45       Brain  San Francisco     351
# 39       Brain         Orange     314
# 72      Breast    Los Angeles    6175
# 87      Breast      San Diego    2632
# 80      Breast         Orange    2243
# 122      Colon    Los Angeles    1977
# 137      Colon      San Diego     648
# 130      Colon         Orange     584
# 162  Esophagus    Los Angeles     118
# 165  Esophagus         Orange      32
# 170  Esophagus      San Diego      28
# 191      Liver    Los Angeles     503
# 199      Liver  San Francisco     172
# 203      Liver    Santa Clara     155
# 217       Lung    Los Angeles     913
# 223       Lung         Orange     311
# 228       Lung      San Diego     275
# 249   Pancreas    Los Angeles     286
# 253   Pancreas         Orange     125
# 259   Pancreas  San Francisco     125
# ...

# %%
# Grouping by Year, Hospital, and Surgery, then count the number of unique surgeries for each hospital in each year
hospital_surgeries_count = df1.groupby(['Year', 'Hospital', 'Surgery']).size().reset_index(name='Count')

# Filtering hospitals that have performed all 11 types of surgeries in each year
hospitals_with_all_surgeries = hospital_surgeries_count.groupby(['Year', 'Hospital']).filter(lambda x: x['Surgery'].nunique() == 11)

# Getting unique hospitals that have performed all 11 types of surgeries in each year
unique_hospitals_with_all_surgeries = hospitals_with_all_surgeries['Hospital'].unique()

# Filtering hospitals that have performed all 11 types of surgeries throughout all the years
consistent_hospitals = []
for hospital in unique_hospitals_with_all_surgeries:
    hospital_data = df1[df1['Hospital'] == hospital]
    if hospital_data['Year'].nunique() == (2021 - 2013 + 1):
        surgeries_per_year = hospital_data.groupby('Year')['Surgery'].nunique()
        if all(surgeries_per_year == 11):
            consistent_hospitals.append(hospital)

# Calculating the percentage of hospitals with at least one surgery for all 11 types throughout all the years
percentage_consistent_hospitals = (len(consistent_hospitals) / df1['Hospital'].nunique()) * 100

print(f"Percentage of hospitals with at least one surgery for all 11 types throughout all the years: {percentage_consistent_hospitals:.2f}%")
print("List of hospitals with all surgeries throughout all the years:")
print(consistent_hospitals)
print(len(consistent_hospitals))
# Out:
# Percentage of hospitals with at least one surgery for all 11 types throughout all the years: 3.25%
# List of hospitals with all surgeries throughout all the years:
# ['Cedars Sinai Medical Center', 'City of Hope Helford Clinical Research Hospital', 'Hoag Memorial Hospital Presbyterian', 'Huntington Memorial Hospital', 'Kaiser Foundation Hospital – Orange County – Anaheim', 'Kaiser Foundation Hospital – Sunset', 'Keck Hospital of University of Southern California', 'Loma Linda University Medical Center', 'Ronald Reagan UCLA Medical Center', 'UC Davis Medical Center', 'UC Irvine Medical Center', 'UC San Diego Health System – Hillcrest Medical Center', 'UC San Francisco Medical Center']
# 13

# %%
# Grouping by Year, Hospital, and Surgery, then count the number of unique surgeries for each hospital in each year
hospital_surgeries_count = df1.groupby(['Year', 'Hospital', 'Surgery']).size().reset_index(name='Count')

# Filtering hospitals that have performed all 11 types of surgeries in each year
hospitals_with_all_surgeries = hospital_surgeries_count.groupby(['Year', 'Hospital']).filter(lambda x: x['Surgery'].nunique() == 11)

# Getting unique hospitals that have performed all 11 types of surgeries in each year
unique_hospitals_with_all_surgeries = hospitals_with_all_surgeries['Hospital'].unique()

# Filtering hospitals that have performed all 11 types of surgeries throughout all the years
consistent_hospitals = []
for hospital in unique_hospitals_with_all_surgeries:
    hospital_data = df1[df1['Hospital'] == hospital]
    if hospital_data['Year'].nunique() == (2021 - 2013 + 1):
        surgeries_per_year = hospital_data.groupby('Year')['Surgery'].nunique()colom
        if all(surgeries_per_year == 11):
            consistent_hospitals.append(hospital)

percentage_consistent_hospitals = (len(consistent_hospitals) / df1['Hospital'].nunique()) * 100

print(f"Percentage of hospitals with at least one surgery for all 11 types throughout all the years: {percentage_consistent_hospitals:.2f}%\n")
print(f"Total number of consistent hospitals: {len(consistent_hospitals)}")
print("\nThe hospitals are as follows:- \n")
for i in range(0, len(consistent_hospitals), 2):
    hospitals_line = consistent_hospitals[i:i+2]
    print(', '.join(hospitals_line))
    print()
# Out:
# Percentage of hospitals with at least one surgery for all 11 types throughout all the years: 3.25%
#
# Total number of consistent hospitals: 13
#
# The hospitals are as follows:-
#
# Cedars Sinai Medical Center, City of Hope Helford Clinical Research Hospital
#
# Hoag Memorial Hospital Presbyterian, Huntington Memorial Hospital
#
# Kaiser Foundation Hospital – Orange County – Anaheim, Kaiser Foundation Hospital – Sunset
#
# Keck Hospital of University of Southern California, Loma Linda University Medical Center
#
# Ronald Reagan UCLA Medical Center, UC Davis Medical Center
#
# UC Irvine Medical Center, UC San Diego Health System – Hillcrest Medical Center
#
# UC San Francisco Medical Center

# %%
 
percentage_consistent_hospitals = (len(consistent_hospitals) / df1['Hospital'].nunique()) * 100

print(f"Percentage of hospitals with at least one surgery for all 11 types throughout all the years: {percentage_consistent_hospitals:.2f}%\n")
print(f"Total number of consistent hospitals: {len(consistent_hospitals)}")
print("\nThe hospitals are as follows:- \n")
for i in range(0, len(consistent_hospitals), 2):
    hospitals_line = consistent_hospitals[i:i+2]
    print(', '.join(hospitals_line))
    print()
# Out:
# Percentage of hospitals with at least one surgery for all 11 types throughout all the years: 3.25%
#
# Total number of consistent hospitals: 13
#
# The hospitals are as follows:-
#
# Cedars Sinai Medical Center, City of Hope Helford Clinical Research Hospital
#
# Hoag Memorial Hospital Presbyterian, Huntington Memorial Hospital
#
# Kaiser Foundation Hospital – Orange County – Anaheim, Kaiser Foundation Hospital – Sunset
#
# Keck Hospital of University of Southern California, Loma Linda University Medical Center
#
# Ronald Reagan UCLA Medical Center, UC Davis Medical Center
#
# UC Irvine Medical Center, UC San Diego Health System – Hillcrest Medical Center
#
# UC San Francisco Medical Center

# %%
df1.head()
# Out:
#    Year Year Index   County  \
# 0  2013      Year1  Alameda
# 1  2013      Year1  Alameda
# 2  2013      Year1  Alameda
# 3  2013      Year1  Alameda
# 4  2013      Year1  Alameda
#
#                                             Hospital    OSHPDID  Surgery  \
# 0                                   Alameda Hospital  106010735  Stomach
# 1                                   Alameda Hospital  106010735    Colon
# 2                                   Alameda Hospital  106010735   Breast
# 3  Alta Bates Summit Medical Center – Alta Bates ...  106010739    Brain
# 4  Alta Bates Summit Medical Center – Alta Bates ...  106010739    Colon
#
#    nCases
# 0       1
# 1       3
# 2       2
# 3       8
# 4      12

# %%
# Group by Year, County, Surgery, and calculate the total number of surgeries
county_surgery_data = df1.groupby(['Year', 'County', 'Surgery'])['nCases'].sum().reset_index()

# Pivot the DataFrame to have Surgery as columns
pivot_df = county_surgery_data.pivot_table(index=['Year', 'County'], columns='Surgery', values='nCases', fill_value=0).reset_index()

# Melt the DataFrame to have a single column for Surgery and another for the total number of cases
melted_df = pivot_df.melt(id_vars=['Year', 'County'], var_name='Surgery', value_name='TotalCases')

# Display the resulting DataFrame
print(melted_df)
# Out:
#       Year     County  Surgery  TotalCases
# 0     2013    Alameda  Bladder          32
# 1     2013     Amador  Bladder           0
# 2     2013      Butte  Bladder           4
# 3     2013  Calaveras  Bladder           0
# 4     2013     Colusa  Bladder           0
# ...    ...        ...      ...         ...
# 4956  2021     Tulare  Stomach           1
# 4957  2021   Tuolumne  Stomach           1
# 4958  2021    Ventura  Stomach          22
# 4959  2021       Yolo  Stomach           0
# 4960  2021       Yuba  Stomach           0
#
# [4961 rows x 4 columns]

# %%
melted_df.to_csv('county_surgery_data.csv', index=False)

# %%
df2 = pd.read_csv("C:/Users/rocka/OneDrive/Desktop/Sem1GMU/AIT 580/Final Project/top_counties3.csv")

# %%
df2.head()
# Out:
#    Year  Surgery         County  nCases
# 0  2013  Bladder    Los Angeles     368
# 1  2013  Bladder    Santa Clara      94
# 2  2013  Bladder      San Diego      74
# 3  2013    Brain    Los Angeles     772
# 4  2013    Brain  San Francisco     364

# %%
county_freq = df2['County'].value_counts()


plt.figure(figsize=(12, 6))
bar_plot = sb.barplot(x=county_freq.index, y=county_freq.values, order=county_freq.index, palette='viridis')


plt.xlabel('County')
plt.ylabel('Frequency')
plt.title('Frequency of Counties')

plt.xticks(rotation=90)


for p in bar_plot.patches:
    bar_plot.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                      ha='center', va='center', xytext=(0, 10), textcoords='offset points')


plt.show()

# %%
top_counties = (df1.groupby(['Year', 'Surgery', 'County'])['nCases']
                 .sum()
                 .reset_index()
                 .groupby(['Year', 'Surgery'])
                 .apply(lambda group: group.nlargest(3, 'nCases'))
                 .reset_index(drop=True))

# Display the result
print(top_counties)
# Out:
#      Year  Surgery         County  nCases
# 0    2013  Bladder    Los Angeles     368
# 1    2013  Bladder    Santa Clara      94
# 2    2013  Bladder      San Diego      74
# 3    2013    Brain    Los Angeles     772
# 4    2013    Brain  San Francisco     364
# ..    ...      ...            ...     ...
# 292  2021   Rectum      San Diego     311
# 293  2021   Rectum         Orange     279
# 294  2021  Stomach    Los Angeles     356
# 295  2021  Stomach         Orange     103
# 296  2021  Stomach      San Diego      80
#
# [297 rows x 4 columns]

# %%
top_counties = (df1.groupby(['Year', 'Surgery', 'County'])['nCases']
                 .sum()
                 .reset_index()
                 .groupby(['Year', 'Surgery'])
                 .apply(lambda group: group.nlargest(3, 'nCases'))
                 .reset_index(drop=True))

# Export the result to a CSV file
top_counties.to_csv('top_counties3.csv', index=False)

# Display the result
print(top_counties)
# Out:
#      Year  Surgery         County  nCases
# 0    2013  Bladder    Los Angeles     368
# 1    2013  Bladder    Santa Clara      94
# 2    2013  Bladder      San Diego      74
# 3    2013    Brain    Los Angeles     772
# 4    2013    Brain  San Francisco     364
# ..    ...      ...            ...     ...
# 292  2021   Rectum      San Diego     311
# 293  2021   Rectum         Orange     279
# 294  2021  Stomach    Los Angeles     356
# 295  2021  Stomach         Orange     103
# 296  2021  Stomach      San Diego      80
#
# [297 rows x 4 columns]
